# %%
import pandas as pd

df = pd.read_excel('Table 1A.xlsx','M')

# %%
read_file = pd.read_csv('Table 1A.csv')

# %%
read_file.to_excel (r'table1a.xlsx', index = None, header=True)

# %%
df
# Out:
#    Unnamed: 0  0 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  30 - 34  \
# 0        2018  144.4  156.2    146.0    148.9    210.5    226.7    228.0
# 1        2019  141.7  157.2    152.4    145.6    198.0    225.9    229.2
# 2        2020  132.4  152.9    159.8    135.7    184.0    221.3    230.6
#
#    35 - 39  40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  70 - 74  \
# 0    237.1    227.6    240.6    261.1    307.1    279.7    214.8    146.0
# 1    238.2    227.0    243.2    246.4    306.8    288.4    220.8    159.6
# 2    234.6    228.2    237.3    238.1    292.1    297.7    227.5    175.3
#
#    75 - 79  80 - 84  >= 85  所有年齡組別
# 0     94.4     78.7   73.3  3421.1
# 1     95.8     79.4   76.2  3431.8
# 2     95.5     82.5   84.2  3409.7

# %%
df = df.rename(columns={'Unnamed: 0':'Year'})

# %%
df
# Out:
#    Year  0 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  30 - 34  35 - 39  \
# 0  2018  144.4  156.2    146.0    148.9    210.5    226.7    228.0    237.1
# 1  2019  141.7  157.2    152.4    145.6    198.0    225.9    229.2    238.2
# 2  2020  132.4  152.9    159.8    135.7    184.0    221.3    230.6    234.6
#
#    40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  70 - 74  75 - 79  \
# 0    227.6    240.6    261.1    307.1    279.7    214.8    146.0     94.4
# 1    227.0    243.2    246.4    306.8    288.4    220.8    159.6     95.8
# 2    228.2    237.3    238.1    292.1    297.7    227.5    175.3     95.5
#
#    80 - 84  >= 85  所有年齡組別
# 0     78.7   73.3  3421.1
# 1     79.4   76.2  3431.8
# 2     82.5   84.2  3409.7

# %%
df = df.iloc[: , :-1]

# %%
df
# Out:
#    Year  0 - 4  5 - 9  10 - 14  15 - 19  20 - 24  25 - 29  30 - 34  35 - 39  \
# 0  2018  144.4  156.2    146.0    148.9    210.5    226.7    228.0    237.1
# 1  2019  141.7  157.2    152.4    145.6    198.0    225.9    229.2    238.2
# 2  2020  132.4  152.9    159.8    135.7    184.0    221.3    230.6    234.6
#
#    40 - 44  45 - 49  50 - 54  55 - 59  60 - 64  65 - 69  70 - 74  75 - 79  \
# 0    227.6    240.6    261.1    307.1    279.7    214.8    146.0     94.4
# 1    227.0    243.2    246.4    306.8    288.4    220.8    159.6     95.8
# 2    228.2    237.3    238.1    292.1    297.7    227.5    175.3     95.5
#
#    80 - 84  >= 85
# 0     78.7   73.3
# 1     79.4   76.2
# 2     82.5   84.2

# %%
df.0-4
# Out:
#   File "<ipython-input-16-835b518e38f8>", line 1
#     df.0-4
#       ^
# SyntaxError: invalid syntax

# %%
df['0 - 4']
# Out:
# 0    144.4
# 1    141.7
# 2    132.4
# Name: 0 - 4, dtype: float64

# %%
df.Year
# Out:
# 0    2018
# 1    2019
# 2    2020
# Name: Year, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x = df.Year
y = df['0 - 4']

# %%
plt.scatter(x, y)

# %%
name = list(df.columns.values)

# %%
y = df[name]

# %%
plt.scatter(x, y)

# %%
dft = df.T
dft
# Out:
#               0       1       2
# Year     2018.0  2019.0  2020.0
# 0 - 4     144.4   141.7   132.4
# 5 - 9     156.2   157.2   152.9
# 10 - 14   146.0   152.4   159.8
# 15 - 19   148.9   145.6   135.7
# 20 - 24   210.5   198.0   184.0
# 25 - 29   226.7   225.9   221.3
# 30 - 34   228.0   229.2   230.6
# 35 - 39   237.1   238.2   234.6
# 40 - 44   227.6   227.0   228.2
# 45 - 49   240.6   243.2   237.3
# 50 - 54   261.1   246.4   238.1
# 55 - 59   307.1   306.8   292.1
# 60 - 64   279.7   288.4   297.7
# 65 - 69   214.8   220.8   227.5
# 70 - 74   146.0   159.6   175.3
# 75 - 79    94.4    95.8    95.5
# 80 - 84    78.7    79.4    82.5
# >= 85      73.3    76.2    84.2

# %%
dft.columns = dft.iloc[0]

# %%
dft
# Out:
# Year     2018.0  2019.0  2020.0
# Year     2018.0  2019.0  2020.0
# 0 - 4     144.4   141.7   132.4
# 5 - 9     156.2   157.2   152.9
# 10 - 14   146.0   152.4   159.8
# 15 - 19   148.9   145.6   135.7
# 20 - 24   210.5   198.0   184.0
# 25 - 29   226.7   225.9   221.3
# 30 - 34   228.0   229.2   230.6
# 35 - 39   237.1   238.2   234.6
# 40 - 44   227.6   227.0   228.2
# 45 - 49   240.6   243.2   237.3
# 50 - 54   261.1   246.4   238.1
# 55 - 59   307.1   306.8   292.1
# 60 - 64   279.7   288.4   297.7
# 65 - 69   214.8   220.8   227.5
# 70 - 74   146.0   159.6   175.3
# 75 - 79    94.4    95.8    95.5
# 80 - 84    78.7    79.4    82.5
# >= 85      73.3    76.2    84.2

# %%
dft = dft[1:]

# %%
dft
# Out:
# Year     2018.0  2019.0  2020.0
# 0 - 4     144.4   141.7   132.4
# 5 - 9     156.2   157.2   152.9
# 10 - 14   146.0   152.4   159.8
# 15 - 19   148.9   145.6   135.7
# 20 - 24   210.5   198.0   184.0
# 25 - 29   226.7   225.9   221.3
# 30 - 34   228.0   229.2   230.6
# 35 - 39   237.1   238.2   234.6
# 40 - 44   227.6   227.0   228.2
# 45 - 49   240.6   243.2   237.3
# 50 - 54   261.1   246.4   238.1
# 55 - 59   307.1   306.8   292.1
# 60 - 64   279.7   288.4   297.7
# 65 - 69   214.8   220.8   227.5
# 70 - 74   146.0   159.6   175.3
# 75 - 79    94.4    95.8    95.5
# 80 - 84    78.7    79.4    82.5
# >= 85      73.3    76.2    84.2

# %%
dft = dft.rename(columns = {'2018.0':'2018','2019.0':'2019','2020.0':'2020'})

# %%
dft
# Out:
# Year     2018.0  2019.0  2020.0
# 0 - 4     144.4   141.7   132.4
# 5 - 9     156.2   157.2   152.9
# 10 - 14   146.0   152.4   159.8
# 15 - 19   148.9   145.6   135.7
# 20 - 24   210.5   198.0   184.0
# 25 - 29   226.7   225.9   221.3
# 30 - 34   228.0   229.2   230.6
# 35 - 39   237.1   238.2   234.6
# 40 - 44   227.6   227.0   228.2
# 45 - 49   240.6   243.2   237.3
# 50 - 54   261.1   246.4   238.1
# 55 - 59   307.1   306.8   292.1
# 60 - 64   279.7   288.4   297.7
# 65 - 69   214.8   220.8   227.5
# 70 - 74   146.0   159.6   175.3
# 75 - 79    94.4    95.8    95.5
# 80 - 84    78.7    79.4    82.5
# >= 85      73.3    76.2    84.2

# %%
dft.columns = dft.columns.astype(int)

# %%
dft.index.name

# %%
dft = dft.rename(columns = {'Year':'age'})
dft
# Out:
# Year      2018   2019   2020
# 0 - 4    144.4  141.7  132.4
# 5 - 9    156.2  157.2  152.9
# 10 - 14  146.0  152.4  159.8
# 15 - 19  148.9  145.6  135.7
# 20 - 24  210.5  198.0  184.0
# 25 - 29  226.7  225.9  221.3
# 30 - 34  228.0  229.2  230.6
# 35 - 39  237.1  238.2  234.6
# 40 - 44  227.6  227.0  228.2
# 45 - 49  240.6  243.2  237.3
# 50 - 54  261.1  246.4  238.1
# 55 - 59  307.1  306.8  292.1
# 60 - 64  279.7  288.4  297.7
# 65 - 69  214.8  220.8  227.5
# 70 - 74  146.0  159.6  175.3
# 75 - 79   94.4   95.8   95.5
# 80 - 84   78.7   79.4   82.5
# >= 85     73.3   76.2   84.2

# %%
x= dft.iloc[:, 0]

# %%
x.values
# Out:
# array([144.4, 156.2, 146. , 148.9, 210.5, 226.7, 228. , 237.1, 227.6,
#        240.6, 261.1, 307.1, 279.7, 214.8, 146. ,  94.4,  78.7,  73.3])

# %%
x_label = x.index
y_value = x.values
plt.scatter(x_label,y_value)

# %%
import numpy as np

# %%
np.std(y_value)
# Out:
# 66.98312506303267

# %%
np.mean(y_value)
# Out:
# 190.06111111111113
